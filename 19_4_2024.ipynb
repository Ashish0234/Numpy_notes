# %% [markdown]
# # Difference between Normal & Binomial distribution

# %%
from numpy import random

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.distplot(random.normal(loc=50, scale=5, size=1000), hist= False, label='normal')
sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist= False, label='binomial')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7040\3049855450.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=5, size=1000), hist= False, label='normal')
# C:\Users\USER\AppData\Local\Temp\ipykernel_7040\3049855450.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=100, p=0.5, size=1000), hist= False, label='binomial')

# %% [markdown]
# # Poisson distribution

# %%
from numpy import random

# %%
x= random.poisson(lam=2, size=10)

# %%
print(x)
# Out:
# [4 3 2 1 1 3 2 1 1 1]

# %% [markdown]
# # Visualization of Poisson Distribution

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.displot(random.poisson(lam=2, size=1000), kde=False)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Difference between Normal and Poisson Distribution

# %%
sns.distplot(random.normal(loc=50, scale=7, size=1000), hist=False, label='normal')
sns.distplot(random.poisson(lam=50, size=1000), hist = False ,label='poisson')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_8252\3710034119.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(loc=50, scale=7, size=1000), hist=False, label='normal')
# C:\Users\USER\AppData\Local\Temp\ipykernel_8252\3710034119.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.poisson(lam=50, size=1000), hist = False ,label='poisson')

# %% [markdown]
# # Uniform Distribution

# %%
x= random.uniform(size=(2,3))
print(x)
# Out:
# [[0.05257416 0.69763377 0.49577735]
#  [0.24918915 0.53385349 0.46395207]]

# %% [markdown]
# # Visualization of Uniform Distribution

# %%
sns.distplot(random.uniform(size=1000), hist=False)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7040\1494691810.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.uniform(size=1000), hist=False)

# %% [markdown]
# # Logistic distribution

# %%
x=random.logistic(loc=1, scale=2, size=(2,3))
print(x)
# Out:
# [[ 0.66290784  4.33130335  5.47986263]
#  [ 2.80215109  3.88393655 -3.12726947]]

# %%
sns.distplot(random.logistic(size=1000), hist=False)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7040\1215292993.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.logistic(size=1000), hist=False)

# %% [markdown]
# # Difference between logistics and normal distribution

# %%
sns.distplot(random.normal(scale=2,size=1000), hist=False, label='normal')
sns.distplot(random.logistic(size=1000), hist=False, label='logistic')
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7040\4292063511.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(scale=2,size=1000), hist=False, label='normal')
# C:\Users\USER\AppData\Local\Temp\ipykernel_7040\4292063511.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.logistic(size=1000), hist=False, label='logistic')

# %% [markdown]
# # Exponential Distribution

# %%
from numpy import random 
x= random.exponential(scale=2, size=(2,3))
print(x)
# Out:
# [[2.64049553 0.44363953 0.90364183]
#  [6.10165872 3.06586722 6.34679975]]

# %% [markdown]
# # Visualization of Exponential Distribution

# %%
sns.distplot(random.exponential(size=1000), hist=False)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7040\4069225469.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.exponential(size=1000), hist=False)

# %% [markdown]
# # Chi Square Distribution

# %%
x= random.chisquare(df=2, size=(2,3))
print(x)
# Out:
# [[2.8655145  1.28982442 3.89271124]
#  [0.93699525 0.34862034 1.29107865]]

# %% [markdown]
# # Visualization of Chi square Distribution

# %%
sns.distplot(random.chisquare(df=1, size=1000),hist=False)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7040\382829674.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.chisquare(df=1, size=1000),hist=False)

# %% [markdown]
# # Rayleigh Distribution

# %%
x= random.rayleigh(scale=2, size=(2,3))
print(x)
# Out:
# [[3.49318075 3.88799971 1.29025002]
#  [1.78908992 2.15808354 2.85118733]]

# %% [markdown]
# # Visualization of Rayleigh Distribution

# %%
sns.distplot(random.rayleigh(size=1000), hist=False)
plt.show()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_7040\2338677170.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.rayleigh(size=1000), hist=False)

# %% [markdown]
# # Pareto Distribution

# %%
x= random.pareto(a=2, size=(2,3))
print(x)
# Out:
# [[1.81145713 0.9192048  0.01453783]
#  [0.06597261 0.20320375 3.04479681]]

# %% [markdown]
# # Visualisation of  Pareto Distribution

# %%
sns.displot(random.pareto(a=2, size=1000),kde=False)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Zipf Distribution

# %%
x= random.zipf(a=2, size=(2,3))
print(x)
# Out:
# [[ 1  1  1]
#  [ 1 13  4]]

# %% [markdown]
# # Visualization of Zipf Distribution

# %%
x=random.zipf(a=2, size=1000)
sns.displot(x[x<10], kde=False)
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
