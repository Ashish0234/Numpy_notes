# %%
from numpy import random

# %%
x=random.choice([3,5,7,9], p=[0.1,0.3,0.6,0.0],size=(100))

# %%
print(x)
# Out:
# [7 3 7 7 5 5 5 7 7 7 5 5 7 7 7 5 5 7 7 7 7 7 7 7 7 7 5 7 7 7 7 5 5 7 7 7 7
#  7 5 7 3 7 3 3 7 5 5 7 5 7 5 7 5 7 5 5 3 5 7 7 7 7 5 7 7 5 7 7 7 7 7 5 7 7
#  7 5 5 7 7 7 5 7 7 5 3 7 7 7 7 7 5 7 7 7 5 7 5 5 5 7]

# %%
x=random.choice([3,5,7,9], p=[0.1,0.3,0.6,0.0],size=(3, 5))

# %%
print(x)
# Out:
# [[7 3 5 7 5]
#  [7 7 7 7 5]
#  [7 7 7 7 5]]

# %%
import numpy as np
arr=np.array([1,2,3,4,5])
random.shuffle(arr)
print(arr)
# Out:
# [2 4 3 1 5]

# %%
arr=np.array([1,2,3,4,5])
print(random.permutation(arr))
# Out:
# [2 5 1 4 3]

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.distplot([0,1,2,3,4,5])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6644\1279057326.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4,5])
# <Axes: ylabel='Density'>

# %%
plt.show()

# %%
sns.distplot([0,1,2,3,4,5],hist=False)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6644\299229084.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot([0,1,2,3,4,5],hist=False)

# %%
#Normal distribution
from numpy import random
x=random.normal(size=(2,3))
print(x)
# Out:
# [[ 1.21283222 -0.36629895 -1.3768496 ]
#  [-0.18491791  0.85079142  2.97969309]]

# %%
x=random.normal(loc=1, scale=2, size=(2,3))
print(x)
# Out:
# [[-1.55239649 -1.04261684 -2.48874234]
#  [ 3.09034217 -0.17205667  0.46351086]]

# %%
#visualization of normal distribution
sns.distplot(random.normal(size=1000), hist= False)
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6644\3738645256.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000), hist= False)

# %%
#Binomial distribution
x= random.binomial(n=10, p=0.5, size=10)
print(x)
# Out:
# [5 4 9 6 7 7 7 7 6 3]

# %%
#Visualization of Binomial Distribution
sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_6644\2276915856.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)
# <Axes: >

# %%
plt.show()
